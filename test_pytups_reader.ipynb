# %%
from pytups import NOAAStudies
import requests
import pandas as pd
import re

# %%
noaastudies = NOAAStudies()

# %%
dfs = noaastudies.get_data(file_urls= ["https://www.ncei.noaa.gov/pub/data/paleo/reconstructions/lechleitner2017/lechleitner2017precip.txt", 
                                       "https://www.ncei.noaa.gov/pub/data/paleo/speleothem/europe/portugal/thatcher2022/thatcher2022-modeloutput_ew.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/paleolimnology/greatplains/elklake/anderson-dean/ofr5diat-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/paleolimnology/greatplains/elklake/anderson-dean/ofr3xray-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/contributions_by_author/willard2019/willard2019-brgdgt-mat.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/icecore/antarctica/buizert2021/buizert2021wdc06a-temp-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/icecore/antarctica/buizert2021/buizert2021spice-accum-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/coral/west_pacific/great_barrier/druffel1999-her_noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/coral/atlantic/swart1996-fave_noaa.txt",              # Sniff line delimiter. Choose from "/n" or "/r/n"
                                       "https://www.ncei.noaa.gov/pub/data/paleo/historical/europe/dobrovolny2010temperature-ann-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/coral/west_pacific/quinn2002-inst_noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/icecore/antarctica/aicc2012taldice-noaa.txt",
                                       "https://www.ncei.noaa.gov/pub/data/paleo/icecore/trop/ortles/ortles2016age-core3-noaa.txt"

                           ])
# Out:
# Error parsing text file https://www.ncei.noaa.gov/pub/data/paleo/contributions_by_author/willard2019/willard2019-brgdgt-mat.txt: 27 columns passed, passed data had 26 columns
# Error parsing text file https://www.ncei.noaa.gov/pub/data/paleo/coral/west_pacific/great_barrier/druffel1999-her_noaa.txt: 1 columns passed, passed data had 5 columns

# %% [markdown]
# https://www.ncei.noaa.gov/pub/data/paleo/coral/west_pacific/great_barrier/druffel1999-her_noaa.txt :
#
# This file has an unknown character at the start
#
# ---------------------------------------------------------------------------
#
#
# https://www.ncei.noaa.gov/pub/data/paleo/contributions_by_author/willard2019/willard2019-brgdgt-mat.txt:
#
# This file has not been formatted correctly. As per teh standard templates, the lines follow a common line terminator. However, in this case the last header value if followed by an extra "\t" charcter, thereby breaking the formatting rule

# %%
for df in dfs:
    display(df)
# Out:
#     Age_BP Rec Dosanas Rec Wanxiang Rec YOK-I Rec Lianhua_short Rec Dayu  \
# 0      -50     -0.0550                 0.5139           -0.8293
# 1      -40     -0.2813       0.1718    0.5208           -0.8057
# 2      -30      0.5244       0.7245   -0.1870           -0.6312   0.6627
# 3      -20      1.1471       0.3307   -0.2829           -0.6700   1.5421
# 4      -10      0.5392       0.7019    0.1344           -0.5753   1.6607
# ..     ...         ...          ...       ...               ...      ...
# 201   1960                             0.6555
# 202   1970
# 203   1980
# 204   1990
# 205   2000
#
#     Rec Cariaco Rec Defore Rec Dandak Rec Huangye1  ... Rec Denniston_G  \
# 0                                          -2.4970  ...
# 1                   2.0712                 -2.1870  ...
# 2                   1.2283                 -1.8327  ...
# 3                   0.4090                 -1.1516  ...
# 4                   0.5368                 -0.4311  ...
# ...
