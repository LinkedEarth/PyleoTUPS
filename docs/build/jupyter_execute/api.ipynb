# %%
from pyleotups import NOAADataset
ds=NOAADataset()
df = ds.search_studies(noaa_id=33213)
dfs = ds.get_data(dataTableIDs="45859")
dfs[0].head()
# Out:
# [2026-04-22 16:23:56,928][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:23:56,928][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:23:57,762][INFO] - Retrieved 1 studies.
#    Site  Hole  Core  Type  Section  Section_Depth  Sample_Depth   Age  TEX86H  \
# 0   NaN   NaN     1   NaN      1.0            4.5         0.045  0.31 -0.1177
# 1   NaN   NaN     1   NaN      1.0           31.5         0.315  0.66 -0.1216
# 2   NaN   NaN     1   NaN      1.0           61.5         0.615  1.04 -0.1183
# 3   NaN   NaN     1   NaN      1.0           90.5         0.905  1.41 -0.1089
# 4   NaN   NaN     1   NaN      1.0          121.5         1.215  1.80 -0.1155
#
#      SST
# 0  30.55
# 1  30.28
# 2  30.51
# 3  31.15
# 4  30.70

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
dsf = ds.search_studies(noaa_id=33213)
df = ds.get_funding()
df.head()
# Out:
# [2026-04-22 16:23:59,207][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:23:59,207][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|███████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 362.48it/s]
# [2026-04-22 16:23:59,857][INFO] - Retrieved 1 studies.
#   StudyID                                          StudyName  \
# 0   33213  Bay of Bengal, Northeast Indian Margin Stable ...
# 1   33213  Bay of Bengal, Northeast Indian Margin Stable ...
# 2   33213  Bay of Bengal, Northeast Indian Margin Stable ...
# 3   33213  Bay of Bengal, Northeast Indian Margin Stable ...
#
#                                        FundingAgency  \
# 0                     US National Science Foundation
# 1             United States Geological Survey (USGS)
# 2     UK Natural Environment Research Council (NERC)
# 3  Japan Society for the Promotion of Science (JSPS)
#
#                 FundingGrant
# 0                 OCE1634774
# 1               NE/L002493/1
# 2  JPMXS05R2900001, 19H05595
# 3            JPMXS05R2900001

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
dsf = ds.search_studies(noaa_id=33213)
df = ds.get_geo()
df.head()
# Out:
# [2026-04-22 16:23:59,876][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:23:59,876][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:00,488][INFO] - Retrieved 1 studies.
#   StudyID          DataType SiteID    SiteName        LocationName  GeoType  \
# 0   33213  PALEOCEANOGRAPHY  58697  IODP U1446  Ocean>Indian Ocean  Feature
#
#   GeometryType  MinLatitude  MaxLatitude  MinLongitude  MaxLongitude  \
# 0        POINT       19.083       19.083        85.733        85.733
#
#   MinElevation MaxElevation
# 0        -1440        -1440

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
dsf = ds.search_studies(noaa_id=33213)
bib, df = ds.get_publications()
df.head()
# Out:
# [2026-04-22 16:24:00,505][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:00,505][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|███████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 495.72it/s]
# [2026-04-22 16:24:01,207][INFO] - Retrieved 1 studies.
#                                               Author  \
# 0  Clemens, Steven; Yamamoto, Masanobu; Thirumala...
#
#                                                Title           Journal  Year  \
# 0  Remote and Local Drivers of Pleistocene South ...  Science Advances  2021
#
#   Volume Number  Pages         Type                     DOI  \
# 0      7     23    NaN  publication  10.1126/sciadv.abg3848
#
#                                         URL           CitationKey StudyID  \
# 0  http://dx.doi.org/10.1126/sciadv.abg3848  M._Remote_2021_33213   33213
#
#                                            StudyName
# 0  Bay of Bengal, Northeast Indian Margin Stable ...

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
df = ds.search_studies(noaa_id=33213)
df.head()
# Out:
# [2026-04-22 16:24:01,242][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:01,250][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:01,876][INFO] - Retrieved 1 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   33213  74834  Bay of Bengal, Northeast Indian Margin Stable ...
#
#            DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  PALEOCEANOGRAPHY         1462580               280        -1460630
#
#    MostRecentYearCE             Coverage [S, N, W, E]  \
# 0              1670  (19.083, 19.083, 85.733, 85.733)
#
#                                           StudyNotes ScienceKeywords  \
# 0  Provided Keywords: Indian monsoon, South Asian...            None
#
#                                        Investigators  \
# 0  Steven Clemens, Masanobu Yamamoto, Kaustubh Th...
#
#                                         Publications  \
# 0  [{'Author': 'Clemens, Steven; Yamamoto, Masano...
#
#                                                Sites  \
# 0  [[{'DataTableID': '45857', 'DataTableName': 'U...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Science Founda...

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
dsf = ds.search_studies(noaa_id=33213)
df = ds.get_tables()
df.head()
# Out:
# [2026-04-22 16:24:01,906][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:01,907][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:02,596][INFO] - Retrieved 1 studies.
#   DataTableID                            DataTableName   TimeUnit  \
# 0       45857       U1446 Benthic Isotopes Clemens2021  cal yr BP
# 1       45864              U1446 Age Model Clemens2021  cal yr BP
# 2       45863                  U1446 Rb/Ca Clemens2021  cal yr BP
# 3       45862                  U1446 Mg/Ca Clemens2021  cal yr BP
# 4       45861  U1446 LeafWax CarbonIsotope Clemens2021  cal yr BP
#
#                                              FileURL  \
# 0  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 1  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 2  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 3  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 4  https://www.ncei.noaa.gov/pub/data/paleo/contr...
#
#                                            Variables     FileDescription  \
# 0  [Site, d13C, d18O, Age, Sample_Depth, Section_...  NOAA Template File
# 1                [Age, Sample_Depth, Comments, Site]  NOAA Template File
# 2  [Section, Type, Hole, Site, Rb/Ca, Rb_normaliz...  NOAA Template File
# 3  [Mg/Ca_SST, Mg/Ca, Age, Sample_Depth, Section_...  NOAA Template File
# 4  [d13C_Ave, d13C_C32, d13C_C30, d13C_C28, d13C_...  NOAA Template File
#
#   SiteID    SiteName        LocationName  GeoType GeometryType  MinLatitude  \
# 0  58697  IODP U1446  Ocean>Indian Ocean  Feature        POINT       19.083
# 1  58697  IODP U1446  Ocean>Indian Ocean  Feature        POINT       19.083
# 2  58697  IODP U1446  Ocean>Indian Ocean  Feature        POINT       19.083
# 3  58697  IODP U1446  Ocean>Indian Ocean  Feature        POINT       19.083
# 4  58697  IODP U1446  Ocean>Indian Ocean  Feature        POINT       19.083
#
#    MaxLatitude  MinLongitude  MaxLongitude MinElevation MaxElevation StudyID  \
# 0       19.083        85.733        85.733        -1440        -1440   33213
# 1       19.083        85.733        85.733        -1440        -1440   33213
# 2       19.083        85.733        85.733        -1440        -1440   33213
# 3       19.083        85.733        85.733        -1440        -1440   33213
# 4       19.083        85.733        85.733        -1440        -1440   33213
#
#                                            StudyName
# 0  Bay of Bengal, Northeast Indian Margin Stable ...
# 1  Bay of Bengal, Northeast Indian Margin Stable ...
# 2  Bay of Bengal, Northeast Indian Margin Stable ...
# 3  Bay of Bengal, Northeast Indian Margin Stable ...
# 4  Bay of Bengal, Northeast Indian Margin Stable ...

# %%
from pyleotups import NOAADataset
ds=NOAADataset()
dsf = ds.search_studies(noaa_id=33213)
df_var = ds.get_variables(dataTableIDs="45859")
df_var.head()
# Out:
# [2026-04-22 16:24:02,638][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:02,638][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=33213&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:03,401][INFO] - Retrieved 1 studies.
#             StudyID SiteID                                            FileURL  \
# DataTableID
# 45859         33213  58697  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 45859         33213  58697  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 45859         33213  58697  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 45859         33213  58697  https://www.ncei.noaa.gov/pub/data/paleo/contr...
# 45859         33213  58697  https://www.ncei.noaa.gov/pub/data/paleo/contr...
#
#               VariableName                                cvDataType  \
# DataTableID
# 45859                  SST  CLIMATE RECONSTRUCTIONS|PALEOCEANOGRAPHY
# 45859               TEX86H                          PALEOCEANOGRAPHY
# 45859                  Age  CLIMATE RECONSTRUCTIONS|PALEOCEANOGRAPHY
# 45859         Sample_Depth  CLIMATE RECONSTRUCTIONS|PALEOCEANOGRAPHY
# 45859        Section_Depth                          PALEOCEANOGRAPHY
#
#                                                         cvWhat  \
# DataTableID
# 45859        earth system variable>temperature variable>tem...
# 45859        chemical composition>compound>organic compound...
# 45859                                         age variable>age
# 45859                                     depth variable>depth
# 45859                  sampling metadata>sample identification
#
#                                                     cvMaterial cvError  \
# DataTableID
# 45859        reconstruction material>organic compound index...    None
# 45859                                                     None    None
# 45859                                                     None    None
# 45859                                                     None    None
# 45859                                                     None    None
#
#                                                         cvUnit cvSeasonality  \
# DataTableID
# 45859                          temperature unit>degree Celsius          None
# 45859                                            dimensionless          None
# 45859        time unit>age unit>calendar kiloyear before pr...          None
# 45859                                        length unit>meter          None
# 45859                                   length unit>centimeter          None
#
#             cvDetail                                           cvMethod  \
# DataTableID
# 45859           None                                               None
# 45859           None  laboratory method>chromatography>liquid chroma...
# 45859           None                                               None
# 45859           None                                               None
# 45859           None                                               None
#
#                                               cvAdditionalInfo cvFormat  \
# DataTableID
# 45859                                 index of Kim et al. 2010  Numeric
# 45859          index of Schouten et al. 2002; extracted lipids  Numeric
# 45859                                                     None  Numeric
# 45859        Spliced  core composite depth below sea floor ...  Numeric
# 45859                       Mid-depth of sample within section  Numeric
#
#                cvShortName
# DataTableID
# 45859                  SST
# 45859               TEX86H
# 45859                  Age
# 45859         Sample_Depth
# 45859        Section_Depth

# %%
import pyleotups as pt
ds = pt.NOAADataset()
df_noaa = ds.search_studies(noaa_id=13156)
df_xml = ds.search_studies(xml_id=1840)
df_noaa.head()
df_xml.head()
# Out:
# [2026-04-22 16:24:03,475][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:03,475][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&NOAAStudyId=13156&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:04,078][INFO] - Retrieved 1 studies.
# [2026-04-22 16:24:04,084][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:04,084][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&xmlId=1840&limit=100
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|███████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 538.28it/s]
# [2026-04-22 16:24:04,703][INFO] - Retrieved 1 studies.
#   StudyID XMLID                                          StudyName  \
# 0    5589  1840  Southern Ocean Midlatitude 160KYr Alkenone SST...
#
#            DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  PALEOCEANOGRAPHY          156360              1951         -154410
#
#    MostRecentYearCE             Coverage [S, N, W, E] StudyNotes  \
# 0                -1  (-45.53, -40.37, 174.93, 177.98)       None
#
#                             ScienceKeywords                   Investigators  \
# 0  [Sea Surface Temperature Reconstruction]  Katharina Pahnke, Julian Sachs
#
#                                         Publications  \
# 0  [{'Author': 'Pahnke, K. and J.P. Sachs', 'Titl...
#
#                                                Sites Funding
# 0  [[{'DataTableID': '7966', 'DataTableName': 'M9...      []

# %%
### Single phrase
df_singlephrase = ds.search_studies(search_text="younger dryas", limit=20)
df_singlephrase.head()
# Out:
# [2026-04-22 16:24:04,728][INFO] - search_studies: Limit set to 20.
# [2026-04-22 16:24:04,728][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=20&searchText=younger+dryas
# Parsing NOAA studies:   0%|                                                                           | 0/20 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 3191.04it/s]
# [2026-04-22 16:24:05,788][WARNING] - Retrieved 20 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:05,790][INFO] - Retrieved 20 studies.
#   StudyID  XMLID                                          StudyName  \
# 0    5898   2709  Aharon 2003 Gulf of Mexico Deglacial Stable Is...
# 1   40939  82023  Alaskan Lake Stable Isotope and Geochemistry D...
# 2   25670  63714  Alkenone SST reconstructions from the eastern ...
# 3    5919   2962  Andrews et al. 1999 Holocene High-Res Labrador...
# 4   11207   9643  Angola-Benguela Front ODP1078C 25KYr Alkenone ...
#
#            DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  PALEOCEANOGRAPHY         18000.0            1000.0        -16050.0
# 1    PALEOLIMNOLOGY         15126.0             -68.0        -13176.0
# 2  PALEOCEANOGRAPHY         29840.0             790.0        -27890.0
# 3  PALEOCEANOGRAPHY         12000.0               0.0        -10050.0
# 4  PALEOCEANOGRAPHY         24740.0              20.0        -22790.0
#
#    MostRecentYearCE                            Coverage [S, N, W, E]  \
# 0             950.0                   (27.76, 27.76, -92.59, -92.59)
# 1            2018.0  (61.489946, 64.311005, -150.00032, -146.666764)
# 2            1160.0                   (-3.38, -0.47, -89.68, -82.07)
# 3            1950.0           (54.6165, 54.7952, -56.1766, -56.0583)
# 4            1930.0                     (-11.92, -11.92, 13.4, 13.4)
#
#                                           StudyNotes  \
# 0                                               None
# 1  Provided Keywords: Paleohydrology, effective m...
# 2  Provided Keywords: Eastern Equatorial Pacific,...
# 3                                               None
# 4  Alkenone sea-surface temperature (SST) estimat...
#
#                                      ScienceKeywords  \
# 0                                               None
# 1  [Pacific Decadal Oscillation, Atmospheric and ...
# 2           [Sea Surface Temperature Reconstruction]
# 3                                               None
# 4           [Sea Surface Temperature Reconstruction]
#
#                                        Investigators  \
# 0                                        Paul Aharon
# 1    Lesleigh Anderson, Bruce Finney, W. Brad Baxter
# 2                  Athanasios Koutavas, Julian Sachs
# 3  Anne Jennings, John Andrews, Lloyd Keigwin, Fr...
# 4  Jung-Hyun Kim, Ralph Schneider, Stefan Mulitza...
#
#                                         Publications  \
# 0  [{'Author': 'Aharon, P.', 'Title': 'Meltwater ...
# 1  [{'Author': 'Anderson, L., Finney, B.P., Baxte...
# 2  [{'Author': 'Koutavas, A., and J.P. Sachs', 'T...
# 3  [{'Author': 'Andrews, J. T., Keigwin, L., Hall...
# 4  [{'Author': 'Kim, J.-H., R.R. Schneider, S. Mu...
#
#                                                Sites  \
# 0  [[{'DataTableID': '33150', 'DataTableName': 'A...
# 1  [[{'DataTableID': '55473', 'DataTableName': 'A...
# 2  [[{'DataTableID': '37533', 'DataTableName': 'V...
# 3  [[{'DataTableID': '33128', 'DataTableName': 'A...
# 4  [[{'DataTableID': '19810', 'DataTableName': 'O...
#
#                                              Funding
# 0                                                 []
# 1  [{'fundingAgency': 'United States Geological S...
# 2  [{'fundingAgency': 'US National Science Founda...
# 3                                                 []
# 4  [{'fundingAgency': 'Bundesministerium für Bild...

# %%
### Logical operator (AND)
df_logop = ds.search_studies(search_text="loess AND stratigraphy", limit=20)
df_logop.head()
# Out:
# [2026-04-22 16:24:05,840][INFO] - search_studies: Limit set to 20.
# [2026-04-22 16:24:05,840][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=20&searchText=loess+AND+stratigraphy
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:06,334][INFO] - Retrieved 1 studies.
#   StudyID XMLID                                         StudyName  \
# 0    5599  2466  Ding et al. 1999 Lingtai Loess Stratigraphy Data
#
#              DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  LOESS AND PALEOSOL         7000000                 0        -6998050
#
#    MostRecentYearCE               Coverage [S, N, W, E] StudyNotes  \
# 0              1950  (35.0667, 35.0667, 107.65, 107.65)       None
#
#   ScienceKeywords Investigators  \
# 0            None  Zhongli Ding
#
#                                         Publications  \
# 0  [{'Author': 'Ding, Z.L., S.F. Xiong, J.M. Sun,...
#
#                                                Sites Funding
# 0  [[{'DataTableID': '32592', 'DataTableName': 'L...      []

# %%
### Wildcards: '_' (single char), '%' (multi-char)
df_wc_1 = ds.search_studies(search_text="f_re", limit=20)
df_wc_2 = ds.search_studies(search_text="pol%", limit=20)
df_wc_1.head(), df_wc_2.head()
# Out:
# [2026-04-22 16:24:06,366][INFO] - search_studies: Limit set to 20.
# [2026-04-22 16:24:06,366][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=20&searchText=f_re
# Parsing NOAA studies:   0%|                                                                           | 0/20 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 6533.69it/s]
# [2026-04-22 16:24:07,233][WARNING] - Retrieved 20 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:07,233][INFO] - Retrieved 20 studies.
# [2026-04-22 16:24:07,238][INFO] - search_studies: Limit set to 20.
# [2026-04-22 16:24:07,238][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=20&searchText=pol%25
# Parsing NOAA studies:   0%|                                                                           | 0/20 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████████████████| 20/20 [00:00<?, ?it/s]
# [2026-04-22 16:24:08,354][WARNING] - Retrieved 20 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:08,354][INFO] - Retrieved 20 studies.
# (  StudyID  XMLID                                          StudyName  \
#  0    5473    652  A High-Resolution Record of Climatic Change in...
#  1   18435  16119  Aishihik Basin, Yukon 12,000 Year Multiproxy L...
#  2   22113  20095  Allen - Lake Riveaux/Abrotonella Rise - ATSE -...
#  3    1926   5011  Anderson fire data from Swamp Lake - IMPD USSW...
#  4   29752  71613  Andreu-Hayles - Ice Cut Dalton Highway - ALCR ...
#
#           DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
#  0  PALEOLIMNOLOGY            1500               -32             450
#  1  PALEOLIMNOLOGY           12906               -57          -10956
#  2       TREE RING             538               -59            1412
#  3    FIRE HISTORY           15819               -10          -13869
#  4       TREE RING              30               -60            1920
#
#     MostRecentYearCE                       Coverage [S, N, W, E]  \
#  0              1982  (45.86694, 45.86694, -95.80361, -95.80361)
#  1              2007    (61.2447, 61.2447, -136.9264, -136.9264)
#  2              2009        (-43.183, -43.183, 146.595, 146.595)
#  3              1960            (37.95, 37.95, -119.82, -119.82)
#  4              2010                (69.0, 69.0, -148.8, -148.8)
#
#                                            StudyNotes  \
#  0  Geochemical and paleontological data sets for ...
#  1  Multiproxy sediment data from Lake WA01, Aishi...
#  2  Post-1930 disturbanes at this site, including ...
#  3                                               None
#  4  North Slope, Alaska, 2010 shrub ring-width dat...
#
#                                       ScienceKeywords  \
#  0                                               None
#  1                                               None
#  2  [ATSE, King Billy pine, Athrotaxis selaginoide...
#  3                                               None
#  4  [Alnus viridis var. crispa (Ait.) Turrill, Ame...
#
#                                         Investigators  \
#  0                        Roger Anderson, Walter Dean
#  1                 Rebecca Rainville, Konrad Gajewski
#  2                                      Kathryn Allen
#  3                                  R. Scott Anderson
#  4  Laia Andreu-Hayles, Kevin Anchukaitis, Javi Ma...
#
#                                          Publications  \
#  0  [{'Author': 'Walter E. Dean, J.P. Bradbury, R....
#  1  [{'Author': 'Rebecca A. Rainville and Konrad G...
#  2  [{'Author': 'K.J. Allen,  J. Ogden, B.M. Buckl...
#  3                                                 []
#  4  [{'Author': 'Laia Andreu-Hayles, Benjamin V. G...
#
#                                                 Sites  \
#  0  [[{'DataTableID': '8031', 'DataTableName': 'El...
#  1  [[{'DataTableID': '28800', 'DataTableName': 'W...
#  2  [[{'DataTableID': '33245', 'DataTableName': 'A...
#  3  [[{'DataTableID': '2062', 'DataTableName': 'US...
#  4  [[{'DataTableID': '42277', 'DataTableName': 'A...
#
#                                               Funding
#  0                                                 []
#  1  [{'fundingAgency': 'Natural Sciences and Engin...
#  2  [{'fundingAgency': 'Australian Research Counci...
#  3                                                 []
#  4  [{'fundingAgency': 'US National Science Founda...  ,
#    StudyID  XMLID                                          StudyName  \
#  0   10437   9101  1,000 Year Ensemble Reconstructions of Tempera...
#  1   36253  77512  10Be Chronology of Khoton Nuur Glacial Landfor...
#  2   22315  20388        2000 Year Tropical Rainfall Reconstructions
#  3   12894  10958  9400 Year Cosmogenic Isotope Data and Solar Ac...
#  4   19281  16968  A global planktic foraminifer census data set ...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
#  0  CLIMATE RECONSTRUCTIONS           950.0             -45.0          1000.0
#  1  CLIMATE RECONSTRUCTIONS         35000.0           16000.0        -33050.0
#  2  CLIMATE RECONSTRUCTIONS          2000.0             -50.0           -50.0
#  3          CLIMATE FORCING          9389.0             -27.0         -7439.0
#  4         PALEOCEANOGRAPHY       6181000.0         1603000.0      -6179050.0
#
#     MostRecentYearCE                        Coverage [S, N, W, E]  \
#  0            1995.0                   (0.0, 90.0, -180.0, 180.0)
#  1          -14050.0  (48.613232, 48.97233, 88.078977, 88.430928)
#  2            2000.0                 (-30.0, 30.0, -180.0, 180.0)
#  3            1977.0                 (-90.0, 90.0, -180.0, 180.0)
#  4        -1601050.0                         (nan, nan, nan, nan)
#
#                                            StudyNotes  \
#  0  Calibration ensemble reconstructions of existi...
#  1                                               None
#  2  Composite reconstruction of low latitude rainf...
#  3  Records of common production rate of cosmogeni...
#  4  Data Compilers: Foley, Kevin; Robinson, Marci;...
#
#                                       ScienceKeywords  \
#  0  [carbon cycle, sensitivity, Air Temperature Re...
#  1                                               None
#  2                     [Precipitation Reconstruction]
#  3                     [Solar Forcing Reconstruction]
#  4                                               None
#
#                                         Investigators  \
#  0  David Frank, Jan Esper, Christoph Raible, Ulf ...
#  1  Peter Strand, Aaron Putnam, Oyungerel Sambuu, ...
#  2  Franziska Lechleitner, Sebastian Breitenbach, ...
#  3  Friedhelm Steinhilber, Jose Abreu, Jürg Beer, ...
#  4  Kevin Foley, Marci Robinson, Harry Dowsett, Ri...
#
#                                          Publications  \
#  0  [{'Author': 'Frank, D.C., J. Esper, C.C. Raibl...
#  1  [{'Author': 'Strand, Peter D., Aaron E. Putnam...
#  2  [{'Author': 'Franziska A. Lechleitner, Sebasti...
#  3  [{'Author': 'Steinhilber, F., J.A. Abreu, J. B...
#  4  [{'Author': 'Dowsett, H., M. Robinson, A. Hayw...
#
#                                                 Sites  \
#  0  [[{'DataTableID': '19235', 'DataTableName': 'F...
#  1  [[{'DataTableID': '48957', 'DataTableName': 'K...
#  2  [[{'DataTableID': '33444', 'DataTableName': 'L...
#  3  [[{'DataTableID': '21230', 'DataTableName': 'T...
#  4  [[{'DataTableID': '1002175', 'DataTableName': ...
#
#                                               Funding
#  0  [{'fundingAgency': 'Swiss National Science Fou...
#  1  [{'fundingAgency': 'US National Science Founda...
#  2  [{'fundingAgency': 'European Union', 'fundingG...
#  3  [{'fundingAgency': 'Swiss National Science Fou...
#  4                                                 []  )

# %%
### Escaping special characters (use backslashes)
df_specchar = ds.search_studies(search_text=r"noaa\-tree\-19260", limit=20)
df_specchar.head()
# Out:
# [2026-04-22 16:24:08,412][INFO] - search_studies: Limit set to 20.
# [2026-04-22 16:24:08,412][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=20&searchText=noaa%5C-tree%5C-19260
# Parsing NOAA studies:   0%|                                                                            | 0/1 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# [2026-04-22 16:24:09,012][INFO] - Retrieved 1 studies.
#   StudyID  XMLID                                         StudyName   DataType  \
# 0   19260  16927  Samonil - Zofinsky prales - ABAL - ITRDB CZEC003  TREE RING
#
#    EarliestYearBP  MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0             363               -60            1587              2010
#
#             Coverage [S, N, W, E]  \
# 0  (48.6667, 48.6667, 14.7, 14.7)
#
#                                           StudyNotes  \
# 0   NOAA Template Chronology file added 2018-12-1...
#
#                                      ScienceKeywords  \
# 0  [Abies alba Mill., European silver fir, ABAL, ...
#
#                                        Investigators  \
# 0  Pavel Šamonil, Petra Doleželová, Ivana Vašíčko...
#
#                                         Publications  \
# 0  [{'Author': 'Pavel Šamonil, Petra Doleželová, ...
#
#                                                Sites Funding
# 0  [[{'DataTableID': '29759', 'DataTableName': 'C...      []

# %%
### Multiple investigators (OR by default)
df_multinv_default = ds.search_studies(investigators=["Wahl, E.R.", "Vose, R.S."])
df_multinv_default.head()
# Out:
# [2026-04-22 16:24:09,046][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:09,046][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&investigators=Wahl%2C+E.R.%7CVose%2C+R.S.&investigatorsAndOr=or
# Parsing NOAA studies:   0%|                                                                           | 0/24 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 3546.98it/s]
# [2026-04-22 16:24:10,164][INFO] - Retrieved 24 studies.
#   StudyID  XMLID                                          StudyName  \
# 0    8405   2665  Ammann and Wahl 2007 N. Hemisphere Temperature...
# 1   18295  15997  California and Western Nevada Precipitation Re...
# 2   19600  17329  European Mean and Spatial Summer Temperature R...
# 3   20465  18279  Hawaiian Islands 500 Year Winter Rainfall and ...
# 4   22454  20650  Living Blended Drought Atlas (LBDA) Version 2 ...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS             950               -30            1000
# 1  CLIMATE RECONSTRUCTIONS             379               -27            1571
# 2  CLIMATE RECONSTRUCTIONS            2088               -53            -138
# 3  CLIMATE RECONSTRUCTIONS             450               -62            1500
# 4  CLIMATE RECONSTRUCTIONS            1950               -75               0
#
#    MostRecentYearCE             Coverage [S, N, W, E]  \
# 0              1980        (0.0, 80.0, -180.0, 180.0)
# 1              1977      (32.5, 42.0, -124.4, -116.5)
# 2              2003         (35.0, 70.0, -25.0, 40.0)
# 3              2012  (18.72, 23.95, -166.74, -156.15)
# 4              2025       (24.0, 50.0, -124.0, -68.0)
#
#                                           StudyNotes  \
# 0  Northern hemisphere multiproxy average annual ...
# 1  Water year (October through following Septembe...
# 2  Spatial (5x5 degree grid) reconstructions of E...
# 3  Reconstructions of Hawaii winter (Dec-Feb) pre...
# 4  The half-degree gridded June-August Palmer Mod...
#
#                                      ScienceKeywords  \
# 0                   [Air Temperature Reconstruction]
# 1            [Precipitation Reconstruction, drought]
# 2  [PAGES Euro-Med 2k, Air Temperature Reconstruc...
# 3  [Precipitation Reconstruction, Other Reconstru...
# 4     [drought, Palmer Drought Index Reconstruction]
#
#                                        Investigators  \
# 0                         Caspar Ammann, Eugene Wahl
# 1                            Henry Diaz, Eugene Wahl
# 2  Jürg Luterbacher, Johannes Werner, Jason Smerd...
# 3  Henry Diaz, Eugene Wahl, Eduardo Zorita, Thoma...
# 4  Edward Gille, Carrie Morrill, Eugene Wahl, Rus...
#
#                                         Publications  \
# 0  [{'Author': 'Ammann, C.M. and E.R. Wahl', 'Tit...
# 1  [{'Author': 'Henry F. Diaz and Eugene R. Wahl'...
# 2  [{'Author': 'J. Luterbacher, J. P. Werner, J. ...
# 3  [{'Author': 'Henry F. Diaz, Eugene R. Wahl, Ed...
# 4  [{'Author': 'Cook, E.R., Seager, R., Heim, R.R...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19446', 'DataTableName': 'P...
# 1  [[{'DataTableID': '28654', 'DataTableName': 'C...
# 2  [[{'DataTableID': '30218', 'DataTableName': 'L...
# 3  [[{'DataTableID': '31159', 'DataTableName': 'H...
# 4  [[{'DataTableID': '33588', 'DataTableName': 'C...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Center for Atm...
# 1                                                 []
# 2  [{'fundingAgency': 'US National Science Founda...
# 3                                                 []
# 4  [{'fundingAgency': 'US National Oceanic and At...

# %%
### Multiple investigators (AND by default)
df_multinv_and = ds.search_studies(investigators=["Wahl, E.R.", "Vose, R.S."], investigatorsAndOr = "and")
df_multinv_and.head()
# Out:
# [2026-04-22 16:24:10,221][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:10,223][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&investigators=Wahl%2C+E.R.%7CVose%2C+R.S.&investigatorsAndOr=or
# Parsing NOAA studies:   0%|                                                                           | 0/24 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 3904.86it/s]
# [2026-04-22 16:24:11,341][INFO] - Retrieved 24 studies.
#   StudyID  XMLID                                          StudyName  \
# 0    8405   2665  Ammann and Wahl 2007 N. Hemisphere Temperature...
# 1   18295  15997  California and Western Nevada Precipitation Re...
# 2   19600  17329  European Mean and Spatial Summer Temperature R...
# 3   20465  18279  Hawaiian Islands 500 Year Winter Rainfall and ...
# 4   22454  20650  Living Blended Drought Atlas (LBDA) Version 2 ...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS             950               -30            1000
# 1  CLIMATE RECONSTRUCTIONS             379               -27            1571
# 2  CLIMATE RECONSTRUCTIONS            2088               -53            -138
# 3  CLIMATE RECONSTRUCTIONS             450               -62            1500
# 4  CLIMATE RECONSTRUCTIONS            1950               -75               0
#
#    MostRecentYearCE             Coverage [S, N, W, E]  \
# 0              1980        (0.0, 80.0, -180.0, 180.0)
# 1              1977      (32.5, 42.0, -124.4, -116.5)
# 2              2003         (35.0, 70.0, -25.0, 40.0)
# 3              2012  (18.72, 23.95, -166.74, -156.15)
# 4              2025       (24.0, 50.0, -124.0, -68.0)
#
#                                           StudyNotes  \
# 0  Northern hemisphere multiproxy average annual ...
# 1  Water year (October through following Septembe...
# 2  Spatial (5x5 degree grid) reconstructions of E...
# 3  Reconstructions of Hawaii winter (Dec-Feb) pre...
# 4  The half-degree gridded June-August Palmer Mod...
#
#                                      ScienceKeywords  \
# 0                   [Air Temperature Reconstruction]
# 1            [Precipitation Reconstruction, drought]
# 2  [PAGES Euro-Med 2k, Air Temperature Reconstruc...
# 3  [Precipitation Reconstruction, Other Reconstru...
# 4     [drought, Palmer Drought Index Reconstruction]
#
#                                        Investigators  \
# 0                         Caspar Ammann, Eugene Wahl
# 1                            Henry Diaz, Eugene Wahl
# 2  Jürg Luterbacher, Johannes Werner, Jason Smerd...
# 3  Henry Diaz, Eugene Wahl, Eduardo Zorita, Thoma...
# 4  Edward Gille, Carrie Morrill, Eugene Wahl, Rus...
#
#                                         Publications  \
# 0  [{'Author': 'Ammann, C.M. and E.R. Wahl', 'Tit...
# 1  [{'Author': 'Henry F. Diaz and Eugene R. Wahl'...
# 2  [{'Author': 'J. Luterbacher, J. P. Werner, J. ...
# 3  [{'Author': 'Henry F. Diaz, Eugene R. Wahl, Ed...
# 4  [{'Author': 'Cook, E.R., Seager, R., Heim, R.R...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19446', 'DataTableName': 'P...
# 1  [[{'DataTableID': '28654', 'DataTableName': 'C...
# 2  [[{'DataTableID': '30218', 'DataTableName': 'L...
# 3  [[{'DataTableID': '31159', 'DataTableName': 'H...
# 4  [[{'DataTableID': '33588', 'DataTableName': 'C...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Center for Atm...
# 1                                                 []
# 2  [{'fundingAgency': 'US National Science Founda...
# 3                                                 []
# 4  [{'fundingAgency': 'US National Oceanic and At...

# %%
### Keywords: hierarchy with '>' and multiple via '|'
df_keywords = ds.search_studies(keywords="earth science>paleoclimate>paleocean>biomarkers")
df_keywords.head()
# Out:
# [2026-04-22 16:24:11,398][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:11,399][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&keywords=earth+science%3Epaleoclimate%3Epaleocean%3Ebiomarkers
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 4147.68it/s]
# [2026-04-22 16:24:12,986][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   22588  20773  2.8 million years of alkenone and TEX86 data a...
# 1   34232  75912  Adélie Drift, East Antarctic Fatty Acid Carbon...
# 2   33472  75092  Agulhas Plateau Biomarker Data and SST Reconst...
# 3   25670  63714  Alkenone SST reconstructions from the eastern ...
# 4   22400  20534  Alkenone paleotemperature estimates, d18O seaw...
#
#            DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  PALEOCEANOGRAPHY       2785481.0             257.0      -2783531.0
# 1  PALEOCEANOGRAPHY           363.0             -48.0          1587.0
# 2  PALEOCEANOGRAPHY       1400000.0          339800.0      -1398050.0
# 3  PALEOCEANOGRAPHY         29840.0             790.0        -27890.0
# 4  PALEOCEANOGRAPHY         18170.0             400.0        -16220.0
#
#    MostRecentYearCE                         Coverage [S, N, W, E]  \
# 0            1693.0            (18.836, 18.836, 116.566, 116.566)
# 1            1998.0  (-66.408333, -66.408333, 140.4405, 140.4405)
# 2         -337850.0        (-41.2561, -41.2561, 25.1564, 25.1564)
# 3            1160.0                (-3.38, -0.47, -89.68, -82.07)
# 4            1550.0       (56.96, 57.872382, -137.10446, -136.43)
#
#                                           StudyNotes  \
# 0  Surface and subsurface temperature difference ...
# 1  Provided Keywords: Paleoceanography, Sea Ice R...
# 2  A new biomarker records of upper water column ...
# 3  Provided Keywords: Eastern Equatorial Pacific,...
# 4  Source reference for EW0408-66JC and EW0408-26...
#
#                             ScienceKeywords  \
# 0  [Sea Surface Temperature Reconstruction]
# 1                                      None
# 2  [Sea Surface Temperature Reconstruction]
# 3  [Sea Surface Temperature Reconstruction]
# 4  [Sea Surface Temperature Reconstruction]
#
#                                        Investigators  \
# 0                    Dawei Li, Meixun Zhao, Jun Tian
# 1  Kate Ashley, James Bendle, Xavier Crosta, Joha...
# 2  Alejandra Cartagena-Sierra, Melissa Berke, Reb...
# 3                  Athanasios Koutavas, Julian Sachs
# 4  Summer Praetorius, Alan Mix, Britta Jensen, Du...
#
#                                         Publications  \
# 0  [{'Author': 'Li, D., M. Zhao, and J. Tian', 'T...
# 1  [{'Author': 'Ashley, Kate, James Bendle, Xavie...
# 2  [{'Author': 'Cartagena-Sierra, A., Berke, M.A....
# 3  [{'Author': 'Koutavas, A., and J.P. Sachs', 'T...
# 4  [{'Author': 'Praetorius, S.K, A.C. Mix, B. Jen...
#
#                                                Sites  \
# 0  [[{'DataTableID': '33711', 'DataTableName': 'O...
# 1  [[{'DataTableID': '47058', 'DataTableName': 'D...
# 2  [[{'DataTableID': '46117', 'DataTableName': 'I...
# 3  [[{'DataTableID': '37533', 'DataTableName': 'V...
# 4  [[{'DataTableID': '33517', 'DataTableName': 'E...
#
#                                              Funding
# 0                                                 []
# 1  [{'fundingAgency': 'European Commission Sevent...
# 2  [{'fundingAgency': 'US National Science Founda...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
### Location hierarchy
df_loc = ds.search_studies(locations="Continent>Africa>Eastern Africa>Zambia")
df_loc.head()
# Out:
# [2026-04-22 16:24:13,069][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:13,070][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&locations=Continent%3EAfrica%3EEastern+Africa%3EZambia
# Parsing NOAA studies:   0%|                                                                           | 0/24 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 1520.46it/s]
# [2026-04-22 16:24:15,093][INFO] - Retrieved 24 studies.
#    StudyID    XMLID                                          StudyName  \
# 0  1000537  1000160  Global Database of Borehole Temperatures and C...
# 1  1000538  1000161  Global Database of Borehole Temperatures and C...
# 2  1000540  1000163  Global Database of Borehole Temperatures and C...
# 3  1000541  1000164  Global Database of Borehole Temperatures and C...
# 4  1000539  1000162  Global Database of Borehole Temperatures and C...
#
#    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  BOREHOLE             450               -22            1500
# 1  BOREHOLE             450               -22            1500
# 2  BOREHOLE             450               -24            1500
# 3  BOREHOLE             450               -24            1500
# 4  BOREHOLE             450               -38            1500
#
#    MostRecentYearCE           Coverage [S, N, W, E]  \
# 0              1972    (-13.92, -13.92, 29.2, 29.2)
# 1              1972    (-13.92, -13.92, 29.2, 29.2)
# 2              1974  (-15.82, -15.82, 27.92, 27.92)
# 3              1974  (-13.08, -13.08, 28.05, 28.05)
# 4              1988  (-12.58, -12.58, 31.65, 31.65)
#
#                                           StudyNotes  \
# 0   This project has as its goal the design, asse...
# 1   This project has as its goal the design, asse...
# 2   This project has as its goal the design, asse...
# 3   This project has as its goal the design, asse...
# 4   This project has as its goal the design, asse...
#
#                                  ScienceKeywords  \
# 0  [Air Temperature Reconstruction, temperature]
# 1  [Air Temperature Reconstruction, temperature]
# 2  [temperature, Air Temperature Reconstruction]
# 3  [temperature, Air Temperature Reconstruction]
# 4  [temperature, Air Temperature Reconstruction]
#
#                                Investigators  \
# 0  Shaopeng Huang, Henry Pollack, Po Yu Shen
# 1  Shaopeng Huang, Henry Pollack, Po Yu Shen
# 2  Shaopeng Huang, Henry Pollack, Po Yu Shen
# 3  Shaopeng Huang, Henry Pollack, Po Yu Shen
# 4  Shaopeng Huang, Henry Pollack, Po Yu Shen
#
#                                         Publications  \
# 0  [{'Author': 'Huang, S., Pollack, H.N., and She...
# 1  [{'Author': 'Huang, S., Pollack, H.N., and She...
# 2  [{'Author': 'Huang, S., Pollack, H.N., and She...
# 3  [{'Author': 'Huang, S., Pollack, H.N., and She...
# 4  [{'Author': 'Huang, S., Pollack, H.N., and She...
#
#                                                Sites  \
# 0  [[{'DataTableID': '1000631', 'DataTableName': ...
# 1  [[{'DataTableID': '1000632', 'DataTableName': ...
# 2  [[{'DataTableID': '1000634', 'DataTableName': ...
# 3  [[{'DataTableID': '1000635', 'DataTableName': ...
# 4  [[{'DataTableID': '1000633', 'DataTableName': ...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Science Founda...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2  [{'fundingAgency': 'US National Science Founda...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
### Species: four-letter codes (uppercase enforced)
df_species = ds.search_studies(species=["ABAL", "PIPO"])
df_species.head()
# Out:
# [2026-04-22 16:24:15,142][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:15,142][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&species=ABAL%7CPIPO&speciesAndOr=or
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 6819.12it/s]
# [2026-04-22 16:24:16,895][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   26070  64380  Azpeleta Tarancón fire data from Mistletoe Can...
# 1   26071  64375  Azpeleta Tarancón fire data from Potato Patch ...
# 2   26073  64376  Azpeleta Tarancón fire data from Snow Canyon, ...
# 3   26072  64374  Azpeleta Tarancón fire data from Solon, south ...
# 4   26074  64381  Azpeleta Tarancón fire data from Turkey Canyon...
#
#        DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  FIRE HISTORY             418               -64            1532
# 1  FIRE HISTORY             271               -65            1679
# 2  FIRE HISTORY             578               -14            1372
# 3  FIRE HISTORY             351               -62            1599
# 4  FIRE HISTORY             343               -53            1607
#
#    MostRecentYearCE                             Coverage [S, N, W, E]  \
# 0              2014  (33.215925, 33.215925, -105.608842, -105.608842)
# 1              2015  (33.043863, 33.043863, -105.724789, -105.724789)
# 2              1964  (33.240746, 33.240746, -105.638039, -105.638039)
# 3              2012  (33.051347, 33.051347, -105.556574, -105.556574)
# 4              2003  (33.099762, 33.099762, -105.549527, -105.549527)
#
#                                           StudyNotes  \
# 0  This site was sampled to assess the spatiotemp...
# 1  This site was sampled to assess the spatiotemp...
# 2  This site was sampled to assess the spatiotemp...
# 3  Tarancón fire data from Solon, south central N...
# 4  This site was sampled to assess the spatiotemp...
#
#                                      ScienceKeywords  \
# 0  [PIST, eastern white pine, Pseudotsuga menzies...
# 1  [eastern white pine, Pinus ponderosa Douglas e...
# 2  [eastern white pine, Pseudotsuga menziesii (Mi...
# 3  [eastern white pine, Pinus ponderosa Douglas e...
# 4  [ponderosa pine, PIPO, western yellow pine, Pi...
#
#                                        Investigators  \
# 0  Alicia Azpeleta Tarancón, Peter Fulé, Andrew S...
# 1  Alicia Azpeleta Tarancón, Peter Fulé, Andrew S...
# 2  Alicia Azpeleta Tarancón, Peter Fulé, Andrew S...
# 3  Alicia Azpeleta Tarancón, Peter Fulé, Andrew S...
# 4  Alicia Azpeleta Tarancón, Peter Fulé, Andrew S...
#
#                                         Publications  \
# 0  [{'Author': 'Azpeleta Tarancon, A., Fulé, P.Z....
# 1  [{'Author': 'Azpeleta Tarancon, A., Fulé, P.Z....
# 2  [{'Author': 'Azpeleta Tarancon, A., Fulé, P.Z....
# 3  [{'Author': 'Azpeleta Tarancon, A., Fulé, P.Z....
# 4  [{'Author': 'Azpeleta Tarancon, A., Fulé, P.Z....
#
#                                                Sites  \
# 0  [[{'DataTableID': '37993', 'DataTableName': 'U...
# 1  [[{'DataTableID': '37994', 'DataTableName': 'U...
# 2  [[{'DataTableID': '37996', 'DataTableName': 'U...
# 3  [[{'DataTableID': '37995', 'DataTableName': 'U...
# 4  [[{'DataTableID': '37997', 'DataTableName': 'U...
#
#                                              Funding
# 0  [{'fundingAgency': 'US Department of Agricultu...
# 1  [{'fundingAgency': 'USDA National Institute of...
# 2                                                 []
# 3  [{'fundingAgency': 'USDA National Institute of...
# 4  [{'fundingAgency': 'USDA National Institute of...

# %%
### Data types: one or more IDs separated by '|'
df_muldatatypes = ds.search_studies(data_type_id="4|18")
df_muldatatypes.head()
# Out:
# [2026-04-22 16:24:16,931][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:16,931][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataTypeID=4%7C18&dataPublisher=NOAA&limit=100
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1548.31it/s]
# [2026-04-22 16:24:18,341][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   10437   9101  1,000 Year Ensemble Reconstructions of Tempera...
# 1   11194   9632  1,100 Year El Niño/Southern Oscillation (ENSO)...
# 2   14193  12194  1000 Year Composite Sea Surface Temperature Re...
# 3   42679  83754    1006-year reconstruction of Rossby wavenumber-5
# 4   36253  77512  10Be Chronology of Khoton Nuur Glacial Landfor...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS           950.0             -45.0          1000.0
# 1  CLIMATE RECONSTRUCTIONS          1050.0             -52.0           900.0
# 2         PALEOCEANOGRAPHY           950.0             -46.0          1000.0
# 3  CLIMATE RECONSTRUCTIONS           950.0             -55.0          1000.0
# 4  CLIMATE RECONSTRUCTIONS         35000.0           16000.0        -33050.0
#
#    MostRecentYearCE                        Coverage [S, N, W, E]  \
# 0            1995.0                   (0.0, 90.0, -180.0, 180.0)
# 1            2002.0                  (-20.0, 20.0, 145.0, -80.0)
# 2            1996.0     (56.66667, 69.48333, -18.1957, 18.36667)
# 3            2005.0                   (0.0, 90.0, -180.0, 180.0)
# 4          -14050.0  (48.613232, 48.97233, 88.078977, 88.430928)
#
#                                           StudyNotes  \
# 0  Calibration ensemble reconstructions of existi...
# 1  An index of canonical ENSO variability for the...
# 2  A set of reconstructions of sea surface temper...
# 3                                               None
# 4                                               None
#
#                                      ScienceKeywords  \
# 0  [carbon cycle, sensitivity, Air Temperature Re...
# 1  [ENSO, Atmospheric and Oceanic Circulation Pat...
# 2                                               None
# 3  [Atmospheric and Oceanic Circulation Patterns ...
# 4                                               None
#
#                                        Investigators  \
# 0  David Frank, Jan Esper, Christoph Raible, Ulf ...
# 1  Jinbao Li, Shang-Ping Xie, Edward Cook, Gang H...
# 2  Laura Cunningham, William Austin, Karen-Luise ...
# 3      Ellie Broadman, Valerie Trouet, Kai Kornhuber
# 4  Peter Strand, Aaron Putnam, Oyungerel Sambuu, ...
#
#                                         Publications  \
# 0  [{'Author': 'Frank, D.C., J. Esper, C.C. Raibl...
# 1  [{'Author': 'Li, J., S.-P. Xie, E.R. Cook, G. ...
# 2  [{'Author': 'Cunningham, L.K., Austin, W.E.N.,...
# 3  [{'Author': 'Broadman, Ellie, Kai Kornhuber, I...
# 4  [{'Author': 'Strand, Peter D., Aaron E. Putnam...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19235', 'DataTableName': 'F...
# 1  [[{'DataTableID': '19791', 'DataTableName': 'e...
# 2  [[{'DataTableID': '24146', 'DataTableName': 'P...
# 3  [[{'DataTableID': '56946', 'DataTableName': 'W...
# 4  [[{'DataTableID': '48957', 'DataTableName': 'K...
#
#                                              Funding
# 0  [{'fundingAgency': 'Swiss National Science Fou...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2  [{'fundingAgency': 'European Commission', 'fun...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
df_latlong = ds.search_studies(min_lat=68, max_lat=69, min_lon=30, max_lon=40)
df_latlong.head()
# Out:
# [2026-04-22 16:24:18,396][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:18,397][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&minLat=68&maxLat=69&minLon=30&maxLon=40
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 9045.30it/s]
# [2026-04-22 16:24:19,659][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   10437   9101  1,000 Year Ensemble Reconstructions of Tempera...
# 1   42679  83754    1006-year reconstruction of Rossby wavenumber-5
# 2   12203  10267  2000 Year Precipitation-Based Southern Oscilla...
# 3   14190  12191  600 Year Ensemble Climate Reconstructions and ...
# 4   12894  10958  9400 Year Cosmogenic Isotope Data and Solar Ac...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS           950.0             -45.0          1000.0
# 1  CLIMATE RECONSTRUCTIONS           950.0             -55.0          1000.0
# 2  CLIMATE RECONSTRUCTIONS          1900.0              -5.0            50.0
# 3  CLIMATE RECONSTRUCTIONS           550.0             -61.0          1400.0
# 4          CLIMATE FORCING          9389.0             -27.0         -7439.0
#
#    MostRecentYearCE         Coverage [S, N, W, E]  \
# 0            1995.0    (0.0, 90.0, -180.0, 180.0)
# 1            2005.0    (0.0, 90.0, -180.0, 180.0)
# 2            1955.0  (-90.0, 90.0, -180.0, 180.0)
# 3            2011.0   (45.0, 85.0, -180.0, 180.0)
# 4            1977.0  (-90.0, 90.0, -180.0, 180.0)
#
#                                           StudyNotes  \
# 0  Calibration ensemble reconstructions of existi...
# 1                                               None
# 2  Reconstruction of a precipitation-based Southe...
# 3  Ensemble Climate Reconstructions, input data f...
# 4  Records of common production rate of cosmogeni...
#
#                                      ScienceKeywords  \
# 0  [carbon cycle, sensitivity, Air Temperature Re...
# 1  [Atmospheric and Oceanic Circulation Patterns ...
# 2  [Atmospheric and Oceanic Circulation Patterns ...
# 3                   [Air Temperature Reconstruction]
# 4                     [Solar Forcing Reconstruction]
#
#                                        Investigators  \
# 0  David Frank, Jan Esper, Christoph Raible, Ulf ...
# 1      Ellie Broadman, Valerie Trouet, Kai Kornhuber
# 2  Hong Yan, Liguang Sun, Yuhong Wang, Wen Huang,...
# 3                      Martin Tingley, Peter Huybers
# 4  Friedhelm Steinhilber, Jose Abreu, Jürg Beer, ...
#
#                                         Publications  \
# 0  [{'Author': 'Frank, D.C., J. Esper, C.C. Raibl...
# 1  [{'Author': 'Broadman, Ellie, Kai Kornhuber, I...
# 2  [{'Author': 'Yan, H., L. Sun, Y. Wang, W. Huan...
# 3  [{'Author': 'Tingley, M.P. and P. Huybers', 'T...
# 4  [{'Author': 'Steinhilber, F., J.A. Abreu, J. B...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19235', 'DataTableName': 'F...
# 1  [[{'DataTableID': '56946', 'DataTableName': 'W...
# 2  [[{'DataTableID': '20526', 'DataTableName': 'S...
# 3  [[{'DataTableID': '24136', 'DataTableName': 'T...
# 4  [[{'DataTableID': '21230', 'DataTableName': 'T...
#
#                                              Funding
# 0  [{'fundingAgency': 'Swiss National Science Fou...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2  [{'fundingAgency': 'National Natural Science F...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'Swiss National Science Fou...

# %%
df_elv = ds.search_studies(min_elevation=100, max_elevation=110)
df_elv.head()
# Out:
# [2026-04-22 16:24:19,702][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:19,704][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&minElev=100&maxElev=110
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 7691.74it/s]
# [2026-04-22 16:24:21,052][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   40170  81293  Abissal Cave, Rainha Cave Geochemical Data fro...
# 1   40477  81622  Adenesky-Filho - Blumenau - SC - CEFI - ITRDB ...
# 2   40939  82023  Alaskan Lake Stable Isotope and Geochemistry D...
# 3   31418  73106        Allen - Tiwi Islands - CAIN - ITRDB AUSL060
# 4   28315  68766      Arnold - Codnor Castle - QUSP - ITRDB BRIT078
#
#          DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0     SPELEOTHEMS         25694.0            4044.0        -23744.0
# 1       TREE RING            13.0             -61.0          1937.0
# 2  PALEOLIMNOLOGY         15126.0             -68.0        -13176.0
# 3       TREE RING            73.0             -57.0          1877.0
# 4       TREE RING           569.0             391.0          1381.0
#
#    MostRecentYearCE                             Coverage [S, N, W, E]  \
# 0           -2094.0            (-5.5782, -5.5642, -37.6659, -37.6432)
# 1            2011.0  (-26.904761, -26.904761, -49.114204, -49.114204)
# 2            2018.0   (61.489946, 64.311005, -150.00032, -146.666764)
# 3            2007.0                  (-11.71, -11.71, 130.83, 130.83)
# 4            1559.0      (53.044355, 53.044355, -1.354599, -1.354599)
#
#                                           StudyNotes  \
# 0  Data contributed as part of SISAL v3 Global Sp...
# 1   Tropical Tree Ring Network SiteID = CEFIS_BRA_07
# 2  Provided Keywords: Paleohydrology, effective m...
# 3  Callitris intratropica ring-width data used fo...
# 4  NOAA Template Raw Measurements file added 2020...
#
#                                      ScienceKeywords  \
# 0                                               None
# 1         [CEFI, Cedrela fissilis Vell., Cedro rosa]
# 2  [Pacific Decadal Oscillation, Atmospheric and ...
# 3  [CAIN, cypress pine, Callitris intratropica R....
# 4                       [Quercus spp. L., oak, QUSP]
#
#                                        Investigators  \
# 0  Francisco Cruz, Mathias Vuille, Stephen Burns,...
# 1  Eduardo Adenesky-Filho, Karin Esemann-Quadros,...
# 2    Lesleigh Anderson, Bruce Finney, W. Brad Baxter
# 3      Kathryn Allen, Jonathan Palmer, Patrick Baker
# 4                       Alison Arnold, Robert Howard
#
#                                         Publications  \
# 0  [{'Author': 'Cruz, Francisco W.; Mathias Vuill...
# 1  [{'Author': 'Unknown Author', 'Title': 'Unknow...
# 2  [{'Author': 'Anderson, L., Finney, B.P., Baxte...
# 3  [{'Author': 'K.J. Allen, M.B. Freund, J.G. Pal...
# 4                                                 []
#
#                                                Sites  \
# 0  [[{'DataTableID': '53529', 'DataTableName': 'A...
# 1  [[{'DataTableID': '54044', 'DataTableName': 'B...
# 2  [[{'DataTableID': '55473', 'DataTableName': 'A...
# 3  [[{'DataTableID': '43922', 'DataTableName': 'A...
# 4  [[{'DataTableID': '40602', 'DataTableName': 'B...
#
#                                              Funding
# 0                                                 []
# 1                                                 []
# 2  [{'fundingAgency': 'United States Geological S...
# 3  [{'fundingAgency': 'Australian Research Counci...
# 4  [{'fundingAgency': 'Historic England', 'fundin...

# %%
### Explicit BP with method
df_timew = ds.search_studies(earliest_year=12000, time_format="BP", time_method="overAny")
df_timew.head()
# Out:
# [2026-04-22 16:24:21,103][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:21,104][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&earliestYear=12000&timeFormat=BP&timeMethod=overAny
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 4019.61it/s]
# [2026-04-22 16:24:22,538][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   10437   9101  1,000 Year Ensemble Reconstructions of Tempera...
# 1   11194   9632  1,100 Year El Niño/Southern Oscillation (ENSO)...
# 2   14193  12194  1000 Year Composite Sea Surface Temperature Re...
# 3   42679  83754    1006-year reconstruction of Rossby wavenumber-5
# 4   22031  20009  1200 Year Atlantic Multidecadal Variability an...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS             950               -45            1000
# 1  CLIMATE RECONSTRUCTIONS            1050               -52             900
# 2         PALEOCEANOGRAPHY             950               -46            1000
# 3  CLIMATE RECONSTRUCTIONS             950               -55            1000
# 4  CLIMATE RECONSTRUCTIONS            1150               -60             800
#
#    MostRecentYearCE                     Coverage [S, N, W, E]  \
# 0              1995                (0.0, 90.0, -180.0, 180.0)
# 1              2002               (-20.0, 20.0, 145.0, -80.0)
# 2              1996  (56.66667, 69.48333, -18.1957, 18.36667)
# 3              2005                (0.0, 90.0, -180.0, 180.0)
# 4              2010                   (0.0, 70.0, -80.0, 0.0)
#
#                                           StudyNotes  \
# 0  Calibration ensemble reconstructions of existi...
# 1  An index of canonical ENSO variability for the...
# 2  A set of reconstructions of sea surface temper...
# 3                                               None
# 4  Summer (May-September) Atlantic Multidecadal V...
#
#                                      ScienceKeywords  \
# 0  [carbon cycle, sensitivity, Air Temperature Re...
# 1  [ENSO, Atmospheric and Oceanic Circulation Pat...
# 2                                               None
# 3  [Atmospheric and Oceanic Circulation Patterns ...
# 4  [Atmospheric and Oceanic Circulation Patterns ...
#
#                                        Investigators  \
# 0  David Frank, Jan Esper, Christoph Raible, Ulf ...
# 1  Jinbao Li, Shang-Ping Xie, Edward Cook, Gang H...
# 2  Laura Cunningham, William Austin, Karen-Luise ...
# 3      Ellie Broadman, Valerie Trouet, Kai Kornhuber
# 4  Jianglin Wang, Bao Yang, Fredrik Ljungqvist, J...
#
#                                         Publications  \
# 0  [{'Author': 'Frank, D.C., J. Esper, C.C. Raibl...
# 1  [{'Author': 'Li, J., S.-P. Xie, E.R. Cook, G. ...
# 2  [{'Author': 'Cunningham, L.K., Austin, W.E.N.,...
# 3  [{'Author': 'Broadman, Ellie, Kai Kornhuber, I...
# 4  [{'Author': 'Jianglin Wang, Bao Yang, Fredrik ...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19235', 'DataTableName': 'F...
# 1  [[{'DataTableID': '19791', 'DataTableName': 'e...
# 2  [[{'DataTableID': '24146', 'DataTableName': 'P...
# 3  [[{'DataTableID': '56946', 'DataTableName': 'W...
# 4  [[{'DataTableID': '33108', 'DataTableName': 'W...
#
#                                              Funding
# 0  [{'fundingAgency': 'Swiss National Science Fou...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2  [{'fundingAgency': 'European Commission', 'fun...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'National Natural Science F...

# %%
### No time_format/time_method → defaults to CE
df_time_defualt = ds.search_studies(earliest_year=1500, latest_year=0)
df_time_defualt.head()
# Out:
# [2026-04-22 16:24:22,659][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:22,660][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# [2026-04-22 16:24:22,661][INFO] - search_studies: time_format not provided; defaulted to 'CE'.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&earliestYear=1500&latestYear=0&timeFormat=CE
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 4076.73it/s]
# [2026-04-22 16:24:24,468][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   22588  20773  2.8 million years of alkenone and TEX86 data a...
# 1   22315  20388        2000 Year Tropical Rainfall Reconstructions
# 2   22390  20667  860,000 Years of foraminifera-bound nitrogen i...
# 3   12894  10958  9400 Year Cosmogenic Isotope Data and Solar Ac...
# 4   15090  12950  A 2000 year long seasonal record of floods in ...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0         PALEOCEANOGRAPHY         2785481               257        -2783531
# 1  CLIMATE RECONSTRUCTIONS            2000               -50             -50
# 2         PALEOCEANOGRAPHY          860000                 0         -858050
# 3          CLIMATE FORCING            9389               -27           -7439
# 4           PALEOLIMNOLOGY            2067               -48            -117
#
#    MostRecentYearCE                         Coverage [S, N, W, E]  \
# 0              1693            (18.836, 18.836, 116.566, 116.566)
# 1              2000                  (-30.0, 30.0, -180.0, 180.0)
# 2              1950                (12.68, 12.68, 119.45, 119.45)
# 3              1977                  (-90.0, 90.0, -180.0, 180.0)
# 4              1998  (45.876667, 45.876667, 10.750556, 10.750556)
#
#                                           StudyNotes  \
# 0  Surface and subsurface temperature difference ...
# 1  Composite reconstruction of low latitude rainf...
# 2  A 860,000-year nitrogen isotope record from So...
# 3  Records of common production rate of cosmogeni...
# 4  This dataset contains ages and thicknesses of ...
#
#                                      ScienceKeywords  \
# 0           [Sea Surface Temperature Reconstruction]
# 1                     [Precipitation Reconstruction]
# 2                                               None
# 3                     [Solar Forcing Reconstruction]
# 4  [Seasonal Resolution (SR), Little Ice Age (LIA...
#
#                                        Investigators  \
# 0                    Dawei Li, Meixun Zhao, Jun Tian
# 1  Franziska Lechleitner, Sebastian Breitenbach, ...
# 2  Haojia Ren, Daniel Sigman, Alfredo Martínez-Ga...
# 3  Friedhelm Steinhilber, Jose Abreu, Jürg Beer, ...
# 4  Stefanie Wirth, Adrian Gilli, Anaëlle Simonnea...
#
#                                         Publications  \
# 0  [{'Author': 'Li, D., M. Zhao, and J. Tian', 'T...
# 1  [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 2  [{'Author': 'Ren, H.; Sigman, D.M.; Martinez-G...
# 3  [{'Author': 'Steinhilber, F., J.A. Abreu, J. B...
# 4  [{'Author': 'Wirth, S. B., A. Gilli, A. Simonn...
#
#                                                Sites  \
# 0  [[{'DataTableID': '33711', 'DataTableName': 'O...
# 1  [[{'DataTableID': '33444', 'DataTableName': 'L...
# 2  [[{'DataTableID': '33610', 'DataTableName': 'M...
# 3  [[{'DataTableID': '21230', 'DataTableName': 'T...
# 4  [[{'DataTableID': '25120', 'DataTableName': 'T...
#
#                                              Funding
# 0                                                 []
# 1  [{'fundingAgency': 'European Union', 'fundingG...
# 2                                                 []
# 3  [{'fundingAgency': 'Swiss National Science Fou...
# 4  [{'fundingAgency': 'Swiss National Science Fou...

# %%
df_recon = ds.search_studies(reconstruction=True)
df_recon.head()
# Out:
# [2026-04-22 16:24:24,515][INFO] - search_studies: Limit defaulted to 100 (PyleoTUPS).
# [2026-04-22 16:24:24,515][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=100&reconstructionsOnly=Y
# Parsing NOAA studies:   0%|                                                                          | 0/100 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|██████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 4272.01it/s]
# [2026-04-22 16:24:25,923][INFO] - Retrieved 100 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   10437   9101  1,000 Year Ensemble Reconstructions of Tempera...
# 1   11194   9632  1,100 Year El Niño/Southern Oscillation (ENSO)...
# 2   14193  12194  1000 Year Composite Sea Surface Temperature Re...
# 3   42679  83754    1006-year reconstruction of Rossby wavenumber-5
# 4   36253  77512  10Be Chronology of Khoton Nuur Glacial Landfor...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS           950.0             -45.0          1000.0
# 1  CLIMATE RECONSTRUCTIONS          1050.0             -52.0           900.0
# 2         PALEOCEANOGRAPHY           950.0             -46.0          1000.0
# 3  CLIMATE RECONSTRUCTIONS           950.0             -55.0          1000.0
# 4  CLIMATE RECONSTRUCTIONS         35000.0           16000.0        -33050.0
#
#    MostRecentYearCE                        Coverage [S, N, W, E]  \
# 0            1995.0                   (0.0, 90.0, -180.0, 180.0)
# 1            2002.0                  (-20.0, 20.0, 145.0, -80.0)
# 2            1996.0     (56.66667, 69.48333, -18.1957, 18.36667)
# 3            2005.0                   (0.0, 90.0, -180.0, 180.0)
# 4          -14050.0  (48.613232, 48.97233, 88.078977, 88.430928)
#
#                                           StudyNotes  \
# 0  Calibration ensemble reconstructions of existi...
# 1  An index of canonical ENSO variability for the...
# 2  A set of reconstructions of sea surface temper...
# 3                                               None
# 4                                               None
#
#                                      ScienceKeywords  \
# 0  [carbon cycle, sensitivity, Air Temperature Re...
# 1  [ENSO, Atmospheric and Oceanic Circulation Pat...
# 2                                               None
# 3  [Atmospheric and Oceanic Circulation Patterns ...
# 4                                               None
#
#                                        Investigators  \
# 0  David Frank, Jan Esper, Christoph Raible, Ulf ...
# 1  Jinbao Li, Shang-Ping Xie, Edward Cook, Gang H...
# 2  Laura Cunningham, William Austin, Karen-Luise ...
# 3      Ellie Broadman, Valerie Trouet, Kai Kornhuber
# 4  Peter Strand, Aaron Putnam, Oyungerel Sambuu, ...
#
#                                         Publications  \
# 0  [{'Author': 'Frank, D.C., J. Esper, C.C. Raibl...
# 1  [{'Author': 'Li, J., S.-P. Xie, E.R. Cook, G. ...
# 2  [{'Author': 'Cunningham, L.K., Austin, W.E.N.,...
# 3  [{'Author': 'Broadman, Ellie, Kai Kornhuber, I...
# 4  [{'Author': 'Strand, Peter D., Aaron E. Putnam...
#
#                                                Sites  \
# 0  [[{'DataTableID': '19235', 'DataTableName': 'F...
# 1  [[{'DataTableID': '19791', 'DataTableName': 'e...
# 2  [[{'DataTableID': '24146', 'DataTableName': 'P...
# 3  [[{'DataTableID': '56946', 'DataTableName': 'W...
# 4  [[{'DataTableID': '48957', 'DataTableName': 'K...
#
#                                              Funding
# 0  [{'fundingAgency': 'Swiss National Science Fou...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2  [{'fundingAgency': 'European Commission', 'fun...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
df_recent = ds.search_studies(recent=True, limit=25)
df_recent.head()
# Out:
# [2026-04-22 16:24:26,007][INFO] - search_studies: Limit set to 25.
# [2026-04-22 16:24:26,008][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=25&recent=true
# Parsing NOAA studies:   0%|                                                                           | 0/25 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 2500.42it/s]
# [2026-04-22 16:24:27,252][WARNING] - Retrieved 25 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:27,253][INFO] - Retrieved 25 studies.
#   StudyID  XMLID                                          StudyName  \
# 0   44619  85076  Cueva de Asiul, Matienzo, Spain Stable Isotope...
# 1   44602  85056  Botuvera Cave Oxygen Isotopes, Sr/Ca and Mg/Ca...
# 2   44599  85055  Palynological data from Cretaceous and Paleoge...
# 3   44579  85075  Great Plains Low-Level Jet 300 Year Wind and M...
# 4   44572  85023  Dannenberg - Buckhorn Mountain Update - PIPO -...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CORALS AND SCLEROSPONGES          1091.0             -60.0           859.0
# 1               SPELEOTHEMS        114472.0            2143.0       -112522.0
# 2                    POLLEN             NaN               NaN             NaN
# 3   CLIMATE RECONSTRUCTIONS           260.0             -72.0          1690.0
# 4                 TREE RING           359.0             -70.0          1591.0
#
#    MostRecentYearCE                           Coverage [S, N, W, E]  \
# 0            2010.0                    (43.32, 43.32, -3.59, -3.59)
# 1            -193.0                (-27.22, -27.22, -49.16, -49.16)
# 2               NaN  (-3.494607, -3.494607, -58.974049, -58.974049)
# 3            2022.0                     (30.0, 42.0, -102.0, -92.0)
# 4            2020.0                  (43.78, 43.78, -103.6, -103.6)
#
#                                           StudyNotes  \
# 0  The data set contains the raw d18O and d13C fo...
# 1                                               None
# 2  The letter "P" in the data table indicates tha...
# 3  Tree-ring-based reconstruction of May-June-Jul...
# 4                         this is an update of sd002
#
#                                      ScienceKeywords  \
# 0  [Precipitation Reconstruction, Atmospheric and...
# 1           [Monsoon, Milankovitch, Heinrich Events]
# 2                        [Vegetation Reconstruction]
# 3  [Atmospheric and Oceanic Circulation Patterns ...
# 4  [PIPO, ponderosa pine, western yellow pine, Pi...
#
#                                        Investigators  \
# 0  Andrew Smith, Philip Barker, Mark Garnett, Arm...
# 1  Lucas Vasconcelos, Francisco Cruz, Juan Pablo ...
# 2                                      Debra Willard
# 3                     Erika Wise, Matthew Dannenberg
# 4  Matthew Dannenberg, Erika Wise, None Harris, A...
#
#                                         Publications  \
# 0                                                 []
# 1  [{'Author': 'Lucas C. Vasconcelos, Francisco W...
# 2  [{'Author': 'Marulanda, S.G., Rodrigues, F.C.G...
# 3  [{'Author': 'Erika K. Wise and Matthew P. Dann...
# 4                                                 []
#
#                                                Sites  \
# 0  [[{'DataTableID': '59446', 'DataTableName': 'S...
# 1  [[{'DataTableID': '59427', 'DataTableName': 'B...
# 2  [[{'DataTableID': '59426', 'DataTableName': 'A...
# 3  [[{'DataTableID': '59411', 'DataTableName': 'U...
# 4  [[{'DataTableID': '59386', 'DataTableName': 'S...
#
#                                              Funding
# 0  [{'fundingAgency': 'UK Natural Environment Res...
# 1  [{'fundingAgency': 'Coordination for the Impro...
# 2  [{'fundingAgency': 'United States Geological S...
# 3  [{'fundingAgency': 'US National Science Founda...
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
### Limit up to first 10 results
df_limit = ds.search_studies(earliest_year=12000, time_format="BP", time_method="overAny", limit=10)
df_limit.head()

### Skip the first 10 results (i.e., get results 11-20)
df_skip = ds.search_studies(earliest_year=12000, time_format="BP", time_method="overAny", limit=10, skip=10)
df_skip.head()
# Out:
# [2026-04-22 16:24:27,291][INFO] - search_studies: Limit set to 10.
# [2026-04-22 16:24:27,291][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=10&earliestYear=12000&timeFormat=BP&timeMethod=overAny
# Parsing NOAA studies:   0%|                                                                           | 0/10 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4924.05it/s]
# [2026-04-22 16:24:28,305][WARNING] - Retrieved 10 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:28,306][INFO] - Retrieved 10 studies.
# [2026-04-22 16:24:28,311][INFO] - search_studies: Limit set to 10.
# [2026-04-22 16:24:28,312][INFO] - search_studies: Input Query includes geographical bounds. Inspect the results to ensure they match your intended region as one study can contain sites across various parts of the world.
# Request URL: https://www.ncei.noaa.gov/access/paleo-search/study/search.json?dataPublisher=NOAA&limit=10&skip=10&earliestYear=12000&timeFormat=BP&timeMethod=overAny
# Parsing NOAA studies:   0%|                                                                           | 0/10 [00:00<?, ?it/s]
# Parsing NOAA studies: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9639.86it/s]
# [2026-04-22 16:24:29,243][WARNING] - Retrieved 10 studies, which is the specified limit. Consider increasing the limit parameter to fetch more studies.
# [2026-04-22 16:24:29,243][INFO] - Retrieved 10 studies.
#   StudyID  XMLID                                          StudyName  \
# 0    9896   8788  200KYr Midge Temperature, Diatom pH, and C/N Data
# 1   33872  75532  2017 Florida Bay Sr/Ca and d18O Data during Hu...
# 2    2605   1676  340 KYr SW Pacific d18O Data and Mg/Ca-based S...
# 3    2614   1685  350 KYr Sea Level Reconstruction and Foraminif...
# 4   14190  12191  600 Year Ensemble Climate Reconstructions and ...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0            PALEOLIMNOLOGY          200000               907         -198050
# 1  CORALS AND SCLEROSPONGES             -67               -67            2017
# 2          PALEOCEANOGRAPHY          340830              1951         -338880
# 3          PALEOCEANOGRAPHY          361500              1000         -359550
# 4   CLIMATE RECONSTRUCTIONS             550               -61            1400
#
#    MostRecentYearCE                       Coverage [S, N, W, E]  \
# 0              1043            (70.558, 70.558, -68.95, -68.95)
# 1              2017  (24.9621, 24.9621, -80.801467, -80.801467)
# 2                -1            (-45.53, -45.53, 174.93, 174.93)
# 3               950                (2.25, 2.25, -90.95, -90.95)
# 4              2011                 (45.0, 85.0, -180.0, 180.0)
#
#                                           StudyNotes  \
# 0  Multiproxy sediment data from Lake CF8, Baffin...
# 1  Seawater Sr/Ca and oxygen isotopes  to complem...
# 2
# 3
# 4  Ensemble Climate Reconstructions, input data f...
#
#                             ScienceKeywords  \
# 0  [Arctic, Air Temperature Reconstruction]
# 1                                      None
# 2  [Sea Surface Temperature Reconstruction]
# 3                [Sea Level Reconstruction]
# 4          [Air Temperature Reconstruction]
#
#                                        Investigators  \
# 0  Yarrow Axford, Jason Briner, Colin Cooke, Donn...
# 1  K. Halimeda Kilbourne, Johan Schijf, Hunter Hu...
# 2  Katharina Pahnke, Rainer Zahn, Henry Elderfiel...
# 3  David Lea, Pamela Martin, Dorothy Pak, Howard ...
# 4                      Martin Tingley, Peter Huybers
#
#                                         Publications  \
# 0  [{'Author': 'Axford, Y., J.P. Briner, C.A. Coo...
# 1  [{'Author': 'Khare, Agraj, Hunter P. Hughes, K...
# 2  [{'Author': 'Shackleton, N.J.', 'Title': 'The ...
# 3  [{'Author': 'Lea, D.W., P.A. Martin, D.K. Pak,...
# 4  [{'Author': 'Tingley, M.P. and P. Huybers', 'T...
#
#                                                Sites  \
# 0  [[{'DataTableID': '18746', 'DataTableName': 'C...
# 1  [[{'DataTableID': '46662', 'DataTableName': 'O...
# 2  [[{'DataTableID': '4289', 'DataTableName': 'MD...
# 3  [[{'DataTableID': '4301', 'DataTableName': 'TR...
# 4  [[{'DataTableID': '24136', 'DataTableName': 'T...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Science Founda...
# 1  [{'fundingAgency': 'US National Science Founda...
# 2                                                 []
# 3                                                 []
# 4  [{'fundingAgency': 'US National Science Founda...

# %%
import pyleotups as pt
ds = pt.PangaeaDataset()

### Can use either DOI strings or numeric IDs (extracted from DOIs)
df = ds.search_studies(
    study_ids=["10.1594/PANGAEA.830587", "10.1594/PANGAEA.830588"]
)
df.head()

df = ds.search_studies(
    study_ids=[830587, 830588]
)
df.head()
# Out:
# [2026-04-22 16:24:29,297][INFO] - Registering Study 830587 via direct lookup.
# [2026-04-22 16:24:32,550][INFO] - Registering Study 830588 via direct lookup.
# [2026-04-22 16:24:35,410][INFO] - Retrived 2 studies
# [2026-04-22 16:24:35,414][INFO] - Retrived 2 studies
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE StudyNotes  \
# 0            1950.0             0.0            1852.0       None
# 1               NaN             NaN               NaN       None
#
#   ScienceKeywords                                      Investigators  \
# 0              []  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1              []  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
#
#                                         Publications        Sites Funding  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...  [MD98-2177]      []
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...  [MD98-2177]      []
#
#   CollectionMembers
# 0              None
# 1              None

# %%
df = ds.search_studies(search_text="Stable oxygen and carbon isotopes", limit = 5)
df.head()
# Out:
# [2026-04-22 16:24:35,445][INFO] - Limit set to 5
# {'q': 'Stable oxygen and carbon isotopes', 'bbox': None, 'limit': 5, 'offset': 0}
# [2026-04-22 16:24:54,054][INFO] - Retrived 7 studies
# [2026-04-22 16:24:54,060][WARNING] - The search contains dataset(s) [759625, 946916] marked as collection. Refer to the 'CollectionMembers' column toidentify respective child datasets.
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
# 2   930941  Benthic stable carbon and oxygen isotopes of C...       4040447.0
# 3   936448  Oxygen and carbon stable isotopes of Neogloboq...        243000.0
# 4   906181  Carbon and oxygen stable isotopes measured on ...        849790.0
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0            1950.0             0.0            1852.0
# 1               NaN             NaN               NaN
# 2            2947.0      -4038497.0            -997.0
# 3            7620.0       -241050.0           -5670.0
# 4           14930.0       -847840.0          -12980.0
#
#                                           StudyNotes  \
# 0                                               None
# 1                                               None
# 2  ODP Leg 130 - Site 806B benthic stable carbon ...
# 3  Stable isotope data on the near-surface polar ...
# 4  High latitude deep water upwelling has the pot...
#
#                                      ScienceKeywords  \
# 0                                                 []
# 1                                                 []
# 2  [benthic d13C, benthic d18O, equatorial Pacifi...
# 3          [Depth/age, Snorri Drift, stabe isotopes]
# 4  [Bering Sea, CO2, Glacial, Sea ice, subarctic,...
#
#                                        Investigators  \
# 0  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 2                                   Bickert, Torsten
# 3                                    Andrews, John T
# 4                                    Worne, Savannah
#
#                                         Publications  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 2  Bickert, Torsten (2026): Benthic stable carbon...
# 3  Andrews, John T (2021): Oxygen and carbon stab...
# 4  Worne, Savannah (2019): Carbon and oxygen stab...
#
#                                   Sites  \
# 0                           [MD98-2177]
# 1                           [MD98-2177]
# 2                            [130-806B]
# 3                           [MD99-2323]
# 4  [323-U1343A, 323-U1343C, 323-U1343E]
#
#                                              Funding CollectionMembers
# 0                                                 []              None
# 1                                                 []              None
# 2  [{'name': 'Integrated Ocean Drilling Program /...              None
# 3                                                 []              None
# 4  [{'name': 'Integrated Ocean Drilling Program /...              None

# %%
df = ds.search_studies(variable_name=["Pulleniatina obliquiloculata δ13C", "Pulleniatina obliquiloculata δ18O"], limit = 5)
df.head()
# Out:
# [2026-04-22 16:24:54,096][INFO] - Limit set to 5
# {'q': 'parameter:Pulleniatina obliquiloculata δ13C parameter:Pulleniatina obliquiloculata δ18O', 'bbox': None, 'limit': 5, 'offset': 0}
# [2026-04-22 16:25:13,175][INFO] - Retrived 12 studies
# [2026-04-22 16:25:13,189][WARNING] - The search contains dataset(s) [759625, 946916] marked as collection. Refer to the 'CollectionMembers' column toidentify respective child datasets.
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
# 2   930941  Benthic stable carbon and oxygen isotopes of C...       4040447.0
# 3   936448  Oxygen and carbon stable isotopes of Neogloboq...        243000.0
# 4   906181  Carbon and oxygen stable isotopes measured on ...        849790.0
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0            1950.0             0.0            1852.0
# 1               NaN             NaN               NaN
# 2            2947.0      -4038497.0            -997.0
# 3            7620.0       -241050.0           -5670.0
# 4           14930.0       -847840.0          -12980.0
#
#                                           StudyNotes  \
# 0                                               None
# 1                                               None
# 2  ODP Leg 130 - Site 806B benthic stable carbon ...
# 3  Stable isotope data on the near-surface polar ...
# 4  High latitude deep water upwelling has the pot...
#
#                                      ScienceKeywords  \
# 0                                                 []
# 1                                                 []
# 2  [benthic d13C, benthic d18O, equatorial Pacifi...
# 3          [Depth/age, Snorri Drift, stabe isotopes]
# 4  [Bering Sea, CO2, Glacial, Sea ice, subarctic,...
#
#                                        Investigators  \
# 0  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 2                                   Bickert, Torsten
# 3                                    Andrews, John T
# 4                                    Worne, Savannah
#
#                                         Publications  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 2  Bickert, Torsten (2026): Benthic stable carbon...
# 3  Andrews, John T (2021): Oxygen and carbon stab...
# 4  Worne, Savannah (2019): Carbon and oxygen stab...
#
#                                   Sites  \
# 0                           [MD98-2177]
# 1                           [MD98-2177]
# 2                            [130-806B]
# 3                           [MD99-2323]
# 4  [323-U1343A, 323-U1343C, 323-U1343E]
#
#                                              Funding CollectionMembers
# 0                                                 []              None
# 1                                                 []              None
# 2  [{'name': 'Integrated Ocean Drilling Program /...              None
# 3                                                 []              None
# 4  [{'name': 'Integrated Ocean Drilling Program /...              None

# %%
df = ds.search_studies(investigators=["Khider, D"], limit = 5)
df.head()
# Out:
# [2026-04-22 16:25:13,245][INFO] - Limit set to 5
# {'q': 'author:Khider, D', 'bbox': None, 'limit': 5, 'offset': 0}
# [2026-04-22 16:25:21,651][INFO] - Retrived 15 studies
# [2026-04-22 16:25:21,657][WARNING] - The search contains dataset(s) [759625, 946916, 830589, 897517] marked as collection. Refer to the 'CollectionMembers' column toidentify respective child datasets.
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
# 2   930941  Benthic stable carbon and oxygen isotopes of C...       4040447.0
# 3   936448  Oxygen and carbon stable isotopes of Neogloboq...        243000.0
# 4   906181  Carbon and oxygen stable isotopes measured on ...        849790.0
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0            1950.0             0.0            1852.0
# 1               NaN             NaN               NaN
# 2            2947.0      -4038497.0            -997.0
# 3            7620.0       -241050.0           -5670.0
# 4           14930.0       -847840.0          -12980.0
#
#                                           StudyNotes  \
# 0                                               None
# 1                                               None
# 2  ODP Leg 130 - Site 806B benthic stable carbon ...
# 3  Stable isotope data on the near-surface polar ...
# 4  High latitude deep water upwelling has the pot...
#
#                                      ScienceKeywords  \
# 0                                                 []
# 1                                                 []
# 2  [benthic d13C, benthic d18O, equatorial Pacifi...
# 3          [Depth/age, Snorri Drift, stabe isotopes]
# 4  [Bering Sea, CO2, Glacial, Sea ice, subarctic,...
#
#                                        Investigators  \
# 0  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 2                                   Bickert, Torsten
# 3                                    Andrews, John T
# 4                                    Worne, Savannah
#
#                                         Publications  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 2  Bickert, Torsten (2026): Benthic stable carbon...
# 3  Andrews, John T (2021): Oxygen and carbon stab...
# 4  Worne, Savannah (2019): Carbon and oxygen stab...
#
#                                   Sites  \
# 0                           [MD98-2177]
# 1                           [MD98-2177]
# 2                            [130-806B]
# 3                           [MD99-2323]
# 4  [323-U1343A, 323-U1343C, 323-U1343E]
#
#                                              Funding CollectionMembers
# 0                                                 []              None
# 1                                                 []              None
# 2  [{'name': 'Integrated Ocean Drilling Program /...              None
# 3                                                 []              None
# 4  [{'name': 'Integrated Ocean Drilling Program /...              None

# %%
df = ds.search_studies(
    search_text="Stable oxygen and carbon isotopes",
    variable_name=["Pulleniatina obliquiloculata δ13C", "Pulleniatina obliquiloculata δ18O"],
    investigators="Khider, D",
    limit = 5
)
df.head()
# Out:
# [2026-04-22 16:25:21,714][INFO] - Limit set to 5
# {'q': 'Stable oxygen and carbon isotopes author:Khider, D parameter:Pulleniatina obliquiloculata δ13C parameter:Pulleniatina obliquiloculata δ18O', 'bbox': None, 'limit': 5, 'offset': 0}
# [2026-04-22 16:25:26,458][INFO] - Retrived 16 studies
# [2026-04-22 16:25:26,469][WARNING] - The search contains dataset(s) [759625, 946916, 830589, 897517] marked as collection. Refer to the 'CollectionMembers' column toidentify respective child datasets.
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
# 2   930941  Benthic stable carbon and oxygen isotopes of C...       4040447.0
# 3   936448  Oxygen and carbon stable isotopes of Neogloboq...        243000.0
# 4   906181  Carbon and oxygen stable isotopes measured on ...        849790.0
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0            1950.0             0.0            1852.0
# 1               NaN             NaN               NaN
# 2            2947.0      -4038497.0            -997.0
# 3            7620.0       -241050.0           -5670.0
# 4           14930.0       -847840.0          -12980.0
#
#                                           StudyNotes  \
# 0                                               None
# 1                                               None
# 2  ODP Leg 130 - Site 806B benthic stable carbon ...
# 3  Stable isotope data on the near-surface polar ...
# 4  High latitude deep water upwelling has the pot...
#
#                                      ScienceKeywords  \
# 0                                                 []
# 1                                                 []
# 2  [benthic d13C, benthic d18O, equatorial Pacifi...
# 3          [Depth/age, Snorri Drift, stabe isotopes]
# 4  [Bering Sea, CO2, Glacial, Sea ice, subarctic,...
#
#                                        Investigators  \
# 0  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 2                                   Bickert, Torsten
# 3                                    Andrews, John T
# 4                                    Worne, Savannah
#
#                                         Publications  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 2  Bickert, Torsten (2026): Benthic stable carbon...
# 3  Andrews, John T (2021): Oxygen and carbon stab...
# 4  Worne, Savannah (2019): Carbon and oxygen stab...
#
#                                   Sites  \
# 0                           [MD98-2177]
# 1                           [MD98-2177]
# 2                            [130-806B]
# 3                           [MD99-2323]
# 4  [323-U1343A, 323-U1343C, 323-U1343E]
#
#                                              Funding CollectionMembers
# 0                                                 []              None
# 1                                                 []              None
# 2  [{'name': 'Integrated Ocean Drilling Program /...              None
# 3                                                 []              None
# 4  [{'name': 'Integrated Ocean Drilling Program /...              None

# %%
df = ds.search_studies(
    min_lat=-10, max_lat=10,
    min_lon=120, max_lon=160
)
df.head()
# Out:
# [2026-04-22 16:25:26,538][INFO] - Limit set to 100
# {'q': '', 'bbox': (120, -10, 160, 10), 'limit': 100, 'offset': 0}
# [2026-04-22 16:29:38,363][INFO] - Retrived 116 studies
# [2026-04-22 16:29:38,405][WARNING] - The search contains dataset(s) [759625, 946916, 830589, 897517, 954692, 971539, 933340, 983391, 887764, 980726, 818970, 950075, 902662, 874319, 899182, 922693, 897104, 839414, 928247, 943130, 921278, 983489, 874687, 924044, 984064, 945550, 807876, 910198, 971967, 835082, 908303, 946134, 770334, 815840, 895987, 922660, 743464, 846405, 952157, 864735, 899188, 899217, 754747, 871885, 824489, 860795, 858091, 754276, 854018, 963567, 877438, 921708, 836359, 786708, 723906, 831190, 820607, 779281, 779239, 779189, 779168, 779059, 779020, 922183, 837186, 987417, 871963, 949555, 948194, 711722, 989939, 854775, 932504, 918714, 700006, 984785, 830815, 787036, 787065, 787043, 787060, 786920, 787094, 786948, 786935, 786992, 787055, 786900, 786805, 786847, 736687, 926072, 854781, 854688, 839181] marked as collection. Refer to the 'CollectionMembers' column toidentify respective child datasets.
#    StudyID                                          StudyName  EarliestYearBP  \
# 0   830587  (Table 2) Age determination of sediment core M...            98.0
# 1   830588  (Table 3) Lead 214 and Lead 210 concentration ...             NaN
# 2   930941  Benthic stable carbon and oxygen isotopes of C...       4040447.0
# 3   936448  Oxygen and carbon stable isotopes of Neogloboq...        243000.0
# 4   906181  Carbon and oxygen stable isotopes measured on ...        849790.0
#
#    MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0            1950.0             0.0            1852.0
# 1               NaN             NaN               NaN
# 2            2947.0      -4038497.0            -997.0
# 3            7620.0       -241050.0           -5670.0
# 4           14930.0       -847840.0          -12980.0
#
#                                           StudyNotes  \
# 0                                               None
# 1                                               None
# 2  ODP Leg 130 - Site 806B benthic stable carbon ...
# 3  Stable isotope data on the near-surface polar ...
# 4  High latitude deep water upwelling has the pot...
#
#                                      ScienceKeywords  \
# 0                                                 []
# 1                                                 []
# 2  [benthic d13C, benthic d18O, equatorial Pacifi...
# 3          [Depth/age, Snorri Drift, stabe isotopes]
# 4  [Bering Sea, CO2, Glacial, Sea ice, subarctic,...
#
#                                        Investigators  \
# 0  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 1  Khider, D, Stott, Lowell D, Emile-Geay, J, Thu...
# 2                                   Bickert, Torsten
# 3                                    Andrews, John T
# 4                                    Worne, Savannah
#
#                                         Publications  \
# 0  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 1  Khider, D; Stott, Lowell D; Emile-Geay, J; Thu...
# 2  Bickert, Torsten (2026): Benthic stable carbon...
# 3  Andrews, John T (2021): Oxygen and carbon stab...
# 4  Worne, Savannah (2019): Carbon and oxygen stab...
#
#                                   Sites  \
# 0                           [MD98-2177]
# 1                           [MD98-2177]
# 2                            [130-806B]
# 3                           [MD99-2323]
# 4  [323-U1343A, 323-U1343C, 323-U1343E]
#
#                                              Funding CollectionMembers
# 0                                                 []              None
# 1                                                 []              None
# 2  [{'name': 'Integrated Ocean Drilling Program /...              None
# 3                                                 []              None
# 4  [{'name': 'Integrated Ocean Drilling Program /...              None
